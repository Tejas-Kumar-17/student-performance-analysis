# %% [markdown]
# # Student Performance Analysis
#
# Internship Task 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("student-mat.csv", sep=';')
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Dataset Exploration

# %%
df.shape
# Out:
# (395, 33)

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ## Analysis

# %%
df['G3'].mean()
# Out:
# np.float64(10.415189873417722)

# %%
(df['G3'] > 15).sum()
# Out:
# np.int64(40)

# %%
df['studytime'].corr(df['G3'])
# Out:
# np.float64(0.09781968965319626)

# %%
df.groupby('sex')['G3'].mean()
# Out:
# sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %% [markdown]
# ## Visualizations

# %%
import matplotlib.pyplot as plt

plt.hist(df['G3'], bins=10)
plt.xlabel("Final Grade (G3)")
plt.ylabel("Number of Students")
plt.title("Distribution of Final Grades")
plt.show()

# %%
plt.scatter(df['studytime'], df['G3'])
plt.show()

# %%
plt.scatter(df['studytime'], df['G3'])
plt.xlabel("Study Time")
plt.ylabel("Final Grade (G3)")
plt.title("Study Time vs Final Grade")
plt.show()

# %%
df.groupby('sex')['G3'].mean().plot(kind='bar')
plt.xlabel("Gender")
plt.ylabel("Average Final Grade")
plt.title("Average Score by Gender")
plt.show()

# %% [markdown]
# ## Explanation

# %% [markdown]
# **🔹Dataset Loding**
#
# The student-mat.csv dataset was loaded using pandas.
# Since the file uses a semicolon (;) as a delimiter, the sep=';' parameter was specified.

# %% [markdown]
# **🔹 Data Cleaning**
#
# The dataset was checked for missing values and duplicate rows to ensure clean data.

# %% [markdown]
# **🔹 Analysis**
#
# Various analyses were performed including average final grade,
# count of high-performing students, correlation between study time and grades,
# and gender-wise performance comparison.

# %% [markdown]
# **🔹 Conclusion**
#
# The analysis shows that study time has a positive but weak relationship with performance.
# Final grades vary across students and gender wise comparison shows slight differences.
# Visualizations helped understand grade distribution and trends clearly.
